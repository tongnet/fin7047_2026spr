# %% [markdown]
# <a href="https://colab.research.google.com/github/tongnet/fin7047_2026spr/blob/main/lec1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install openai
from openai import OpenAI

# Initialize client
client = OpenAI(api_key="enter api key here")

def generate_paris_itinerary(days=3, budget_per_day=250):
    prompt = f"""
    Generate a detailed {days}-day travel itinerary for Paris with daily activities and an estimated budget.
    The budget per day is €{budget_per_day}. Include attractions, dining suggestions, and a breakdown of costs.
    """

    # New API call style
    response = client.chat.completions.create(
        model="gpt-4o-mini",   # or "gpt-4o", "gpt-4.1" depending on your plan
        messages=[
            {"role": "system", "content": "You are a helpful travel assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=1000,
        temperature=0.7
    )

    return response.choices[0].message.content.strip()

# Generate and print itinerary
itinerary = generate_paris_itinerary(days=3, budget_per_day=250)
print(itinerary)
# Out:
# **3-Day Travel Itinerary for Paris**
#
# **Day 1: Classic Parisian Experience**
#
# **Morning:**
# - **Breakfast at Café de Flore**: Enjoy a traditional French breakfast of croissants, coffee, and fresh juice.
#   - Cost: €15
# - **Visit the Louvre Museum**: Explore the world’s largest art museum. Pre-book your tickets online to avoid long lines.
#   - Cost: €17
#
# **Afternoon:**
# - **Lunch at Le Relais de l’Entrecôte**: Famous for its steak-frites and secret sauce.
#   - Cost: €25
# - **Stroll through the Tuileries Garden**: Enjoy a leisurely walk through the beautiful gardens.
# - **Visit the Musée de l'Orangerie**: Famous for Monet’s Water Lilies.
#   - Cost: €12.50
#
# **Evening:**
# - **Dinner at Le Procope**: Dine at the oldest café in Paris, known for its historical significance and classic French cuisine.
#   - Cost: €40
# - **Seine River Cruise**: Enjoy a scenic evening cruise to see the city lights and iconic landmarks.
#   - Cost: €15
#
# **Estimated Day 1 Total**: €124.50
#
# ---
#
# **Day 2: Montmartre and Culture**
#
# **Morning:**
# - **Breakfast at Angelina**: Famous for its hot chocolate and pastries.
#   - Cost: €20
# - **Visit Sacré-Cœur Basilica**: Enjoy the stunning views of Paris from the top.
#   - Cost: Free
#
# **Afternoon:**
# - **Lunch at Le Consulat**: A charming café in Montmartre with great views.
#   - Cost: €20
# - **Explore Montmartre**: Visit Place du Tertre and the art stalls, where local artists sell their work.
# - **Visit the Musée de l'Orangerie or the Dali Museum**: If you prefer surrealism, consider this alternative.
#   - Cost: €12
#
# **Evening:**
# - **Dinner at La Maison Rose**: A picturesque restaurant in Montmartre.
#   - Cost: €35
# - **Moulin Rouge Show**: Experience a classic Parisian cabaret.
#   - Cost: €100 (with dinner package)
#
# **Estimated Day 2 Total**: €317
#
# ---
#
# **Day 3: Gardens and Historical Sites**
#
# **Morning:**
# - **Breakfast at a local boulangerie**: Grab a pastry and coffee.
#   - Cost: €10
# - **Visit the Palace of Versailles**: Take a short train ride to explore the opulent palace and gardens.
#   - Cost: €20 (train ticket + entrance)
#
# **Afternoon:**
# - **Lunch at La Petite Venise**: Located in the gardens of Versailles.
#   - Cost: €25
# - **Explore the Gardens of Versailles**: Spend the afternoon wandering through the vast gardens.
#   - Cost: Free
#
# **Evening:**
# - **Return to Paris**.
# - **Dinner at Café des 2 Moulins**: Famous from the movie Amélie.
#   - Cost: €30
# - **Visit the Eiffel Tower**: Pre-book tickets to go to the summit for stunning views of the city at night.
#   - Cost: €25
#
# **Estimated Day 3 Total**: €230
#
# ---
#
# ### Overall Estimated Budget Summary:
# - **Day 1 Total**: €124.50
# - **Day 2 Total**: €317
# - **Day 3 Total**: €230
#
# **Total for 3 Days**: €671.50
#
# ### Notes:
# - This itinerary does exceed the daily budget on Day 2; consider alternatives like skipping the Moulin Rouge show or choosing different dining options.
# - Adjustments can be made based on personal preferences, such as opting for less expensive dining or alternative attractions.
# - Make sure to check the opening hours and book tickets in advance where necessary to maximize your time!

# %%
#!pip install matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, Rectangle

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Draw the boxes and circles in three columns
ax.text(0.2, 0.9, 'Bank', fontsize=14, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.5, 0.9, 'Insurer', fontsize=14, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.8, 0.9, 'Asset\nManager', fontsize=14, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))

# Draw the customer circles in three columns
ax.text(0.2, 0.5, 'Customer', fontsize=12, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.5, 0.5, 'Customer', fontsize=12, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))
ax.text(0.8, 0.5, 'Customer', fontsize=12, ha='center', va='center', bbox=dict(facecolor='white', edgecolor='black'))

# Draw the arrows (top to bottom to represent the transactions)
arrowprops = dict(facecolor='black', arrowstyle='-|>', lw=1.5, mutation_scale=20)

# Bank to Customer (left column, two arrows)
ax.add_patch(FancyArrowPatch((0.15, 0.83), (0.15, 0.53), **arrowprops))
ax.add_patch(FancyArrowPatch((0.25, 0.53), (0.25, 0.83), **arrowprops))
ax.text(0.14, 0.7, 'Loan', fontsize=10, ha='right', va='center')
ax.text(0.26, 0.7, 'Interest', fontsize=10, ha='left', va='center')

# Insurer to Customer (middle column, two arrows)
ax.add_patch(FancyArrowPatch((0.45, 0.83), (0.45, 0.53), **arrowprops))
ax.add_patch(FancyArrowPatch((0.55, 0.53), (0.55, 0.83), **arrowprops))
ax.text(0.44, 0.7, 'Policy', fontsize=10, ha='right', va='center')
ax.text(0.56, 0.7, 'Premium', fontsize=10, ha='left', va='center')

# Asset Manager to Customer (right column)
ax.add_patch(FancyArrowPatch((0.75, 0.83), (0.75, 0.53), **arrowprops))
ax.add_patch(FancyArrowPatch((0.85, 0.53), (0.85, 0.83), **arrowprops))
ax.text(0.74, 0.7, 'Investment', fontsize=10, ha='right', va='center')
ax.text(0.89, 0.7, 'Fee', fontsize=10, ha='right', va='center')

# Set limits and remove axes
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis('off')

# Show the plot
plt.show()
